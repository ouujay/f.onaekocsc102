# %%
import pandas as pd
#df = pd.read_csv('pokemon_data.csv')
df = pd.read_csv('pokemon_data.txt', delimiter='\t')
print(dftxt)
#print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#reading headers
df.columns
# read each column
#print(df['Name'][0:5])
#print(df[['Name', 'Type 1', 'HP']])
#read each row
#print(df.iloc[1])
#print(df.iloc[2,1])
#for index, row in df.iterrows():
#    print(index, row['Name'])

#read each specific location(r,c)
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Total             405
# Name: 1, dtype: object

# %%
#finding data that isnt just interger base.. its based on more tetual information 
df.loc[df['Type 1'] == "Fire"]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
#this is for another one
df.loc[df['Type 2'] == "Flying"]
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard      Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 15    12                 Butterfree       Bug  Flying   60      45       50
# 20    16                     Pidgey    Normal  Flying   40      45       40
# 21    17                  Pidgeotto    Normal  Flying   63      60       55
# ..   ...                        ...       ...     ...  ...     ...      ...
# 730  662                Fletchinder      Fire  Flying   62      73       55
# 731  663                 Talonflame      Fire  Flying   78      81       71
# 734  666                   Vivillon       Bug  Flying   80      52       50
# 771  701                   Hawlucha  Fighting  Flying   78      92       75
# 793  717                    Yveltal      Dark  Flying  126     131       95
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
#so this sorts the value by name
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#the false makes it tpo decend when its actually supposed to be ascending 
df.sort_values('Name', ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
#this is for combing .. if you wnat both to accend 
#df.sort_values(['Type 1', 'HP'], ascending=True)
#if you want one to decend and the other to acend
df.sort_values(['Type 1', 'HP'], ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#always cross check you dont want to be caught on the wrong side 
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
#to delete a column
#df = df.drop(columns=['Total'])
df['Total'] = df.iloc[:, 4:10].sum(axis=1)

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Speed  Generation  Legendary  \
# 0  1              Bulbasaur  Grass  Poison     45           1      False
# 1  2                Ivysaur  Grass  Poison     60           1      False
# 2  3               Venusaur  Grass  Poison     80           1      False
# 3  3  VenusaurMega Venusaur  Grass  Poison     80           1      False
# 4  4             Charmander   Fire     NaN     65           1      False
#
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def
# 0    318  45      49       49       65       65
# 1    405  60      62       63       80       80
# 2    525  80      82       83      100      100
# 3    625  80     100      123      122      120
# 4    309  39      52       43       60       50

# %%
#saving data frames
#df.to_csv('modified.csv',index=False)
df.to_excel('modified.xlsx',index=False)

# %%
# you can use and or "or" to seperate the conditions
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
new_df = new_df.reset_index(drop=True, inplace=True)

# %%
# the ~ sign is used to drop all the megas instead
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Speed  Generation  \
# 3      3      VenusaurMega Venusaur     Grass    Poison     80           1
# 7      6  CharizardMega Charizard X      Fire    Dragon    100           1
# 8      6  CharizardMega Charizard Y      Fire    Flying    100           1
# 12     9    BlastoiseMega Blastoise     Water       NaN     78           1
# 19    15      BeedrillMega Beedrill       Bug    Poison    145           1
# 23    18        PidgeotMega Pidgeot    Normal    Flying    121           1
# 71    65      AlakazamMega Alakazam   Psychic       NaN    150           1
# 87    80        SlowbroMega Slowbro     Water   Psychic     30           1
# 102   94          GengarMega Gengar     Ghost    Poison    130           1
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    100           1
# 137  127          PinsirMega Pinsir       Bug    Flying    105           1
# ...

# %%
import re
# if you want the pi to be in beginning  only ^
df.loc[df['Name'].str.contains('pi[a-z]*', flags=re.I, regex=True)]
# Out:
#        #                     Name    Type 1    Type 2  Speed  Generation  \
# 13    10                 Caterpie       Bug       NaN     45           1
# 20    16                   Pidgey    Normal    Flying     56           1
# 21    17                Pidgeotto    Normal    Flying     71           1
# 22    18                  Pidgeot    Normal    Flying    101           1
# 23    18      PidgeotMega Pidgeot    Normal    Flying    121           1
# 30    25                  Pikachu  Electric       NaN     90           1
# 42    37                   Vulpix      Fire       NaN     65           1
# 76    70               Weepinbell     Grass    Poison     55           1
# 84    78                 Rapidash      Fire       NaN    105           1
# 136  127                   Pinsir       Bug       NaN     85           1
# 137  127        PinsirMega Pinsir       Bug    Flying    105           1
# 181  167                 Spinarak       Bug    Poison     30           2
# ...

# %%
#this changes the fire in type 1 to flammer 
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flammer'
df
# Out:
#        #                   Name   Type 1  Type 2  Speed  Generation  \
# 0      1              Bulbasaur    Grass  Poison     45           1
# 1      2                Ivysaur    Grass  Poison     60           1
# 2      3               Venusaur    Grass  Poison     80           1
# 3      3  VenusaurMega Venusaur    Grass  Poison     80           1
# 4      4             Charmander  Flammer     NaN     65           1
# ..   ...                    ...      ...     ...    ...         ...
# 795  719                Diancie     Rock   Fairy     50           6
# 796  719    DiancieMega Diancie     Rock   Fairy    110           6
# 797  720    HoopaHoopa Confined  Psychic   Ghost     70           6
# 798  720     HoopaHoopa Unbound  Psychic    Dark     80           6
# 799  721              Volcanion  Flammer   Water     70           6
#
#      Legendary  Total  HP  Attack  Defense  Sp. Atk  Sp. Def Type  1 Type  2
# ...

# %%
#this changes the poison in type 1 to flax
df.loc[df['Type 2'] == 'Poison', 'Type 2'] = 'Flax'
df
# Out:
#        #                   Name   Type 1 Type 2  Speed  Generation  Legendary  \
# 0      1              Bulbasaur    Grass   Flax     45           1      False
# 1      2                Ivysaur    Grass   Flax     60           1      False
# 2      3               Venusaur    Grass   Flax     80           1      False
# 3      3  VenusaurMega Venusaur    Grass   Flax     80           1      False
# 4      4             Charmander  Flammer    NaN     65           1      False
# ..   ...                    ...      ...    ...    ...         ...        ...
# 795  719                Diancie     Rock  Fairy     50           6       True
# 796  719    DiancieMega Diancie     Rock  Fairy    110           6       True
# 797  720    HoopaHoopa Confined  Psychic  Ghost     70           6       True
# 798  720     HoopaHoopa Unbound  Psychic   Dark     80           6       True
# 799  721              Volcanion  Flammer  Water     70           6       True
#
# ...
